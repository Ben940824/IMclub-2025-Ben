# %% [markdown]
# # 函數
# ## 函數的定義方式

# %%
def roast(stuff):
    print("你看起來就像", stuff, sep="")
    # 沒有回傳值

roast("茶碗蒸")

# %% [markdown]
# https://youtu.be/XmthZCqKRp8?si=XE9W49S-iGIpchXG

# %%
def introduce(name, country, skill):
    print("我是", name, "，來自", country, "，擅長", skill, sep="")
    # 沒有回傳值

# 用順序傳入函數
introduce("椅子", "香港", "評論醋飯")

# 用關鍵字傳入函數
introduce(country="台灣", name="超哥", skill="超派鐵拳")

# %% [markdown]
# https://youtu.be/EMMg2zLybOI?si=I6yyUXUu84j9HwKZ

# %%
def f(x):
    return 2 * x + 5
a = 10
b = f(a)

# %% [markdown]
# ## 遞迴函數 - 階乘

# %%
def factorial(n):
    if n == 0: # 初始條件
        return 1
    else:
        return n * factorial(n - 1) # 遞迴關係

print(factorial(5))
print(factorial(10))

# %% [markdown]
# ## 函數 - 課堂練習

# %% [markdown]
# ### b513. 判斷質數

# %%
def is_prime(number):
  # 請在這邊填上你的程式碼，並在最後繳交「完整程式碼」

n = int(input())
for i in range(n):
  x = int(input())
  if is_prime(x):
    print('Y')
  else:
    print('N')

# %% [markdown]
# ### c002. f91

# %%
def f91(n):
  # 請在這邊填上你的程式碼
  # 並在最後繳交「完整程式碼」

while True:
  try:
    n = int(input())
    if n == 0:
      break
    else:
      print(f"f91({n}) = {f91(n)}")
  except:
    break

# %% [markdown]
# ### a227. 河內塔 (optional)

# %%
def hanoi(n, start, middle, goal):
  if n == 1:
    # 請在這邊填上你的程式碼，並在最後繳交「完整程式碼」
  else:
    # 請在這邊填上你的程式碼，並在最後繳交「完整程式碼」

while True:
  try:
    n = int(input())
    # 請在這邊填上你的程式碼，並在最後繳交「完整程式碼」
  except:
    break

# %% [markdown]
# ## 物件

# %% [markdown]
# ### 內建物件

# %%
# 可變物件
l = [1, 2, 3]
l[1] = 1
print(l) # [1, 1, 3]

# %%
# 不可變物件
s = "Hello"
s[1] = "a" # Error
print(s)

# %% [markdown]
# ### 自定義物件

# %%
class Dog:
    # 建構子：對物件的屬性進行初始化
    def __init__(self, name, age, breed):
        self.name = name
        self.age = age
        self.breed = breed
    # 方法
    def bark(self):
        print("我是", self.name, "，汪！")

# %%
# 建立 Dog 類別的實例
dog_1 = Dog("多比", 4, "薩摩耶")
dog_2 = Dog(age=2, name="金寶", breed="黃金獵犬")
dog_3 = Dog("可愛狗勾", None, "米克斯")

dog_1.bark() #我是 多比 ，汪！
dog_2.bark() #我是 金寶 ，汪！
dog_3.bark() #我是 可愛狗勾 ，汪！

# %% [markdown]
# https://www.youtube.com/shorts/Uz9k6QGqXj0

# %% [markdown]
# ## 模組與套件

# %% [markdown]
# ### `math` 內建模組
# https://docs.python.org/zh-tw/3/library/math.html

# %%
import math

angle = math.radians(45)
sin_value = math.sin(angle)
cos_value = math.cos(angle)
tan_value = math.tan(angle)

print("sin(45°):", sin_value)
print("cos(45°):", cos_value)
print("tan(45°):", tan_value)

exp_value = math.exp(2)  # 計算e的次方
log_value = math.log(math.e)  # 計算以e為底的對數

print("e 的次方:", exp_value)
print("以 e 為底的 e 的對數:", log_value)

absolute_value = math.fabs(-5)  # 取絕對值
ceiled_value = math.ceil(4.2)  # 向上取整
floored_value = math.floor(7.8)  # 向下取整

# %% [markdown]
# #### 小試身手
# 請透過 https://docs.python.org/zh-tw/3/library/math.html 查詢你需要使用的函數

# %%
import math
# 請用 math 模組計算 20 的階乘並印出

# 請用 math 模組計算 C(20, 3) 的值並印出

# 請用 math 模組計算 -0.00001 的絕對值後印出

# 請用 math 模組計算 8765 和 4321 的最大公因數後印出
# Out:
# 1

# %% [markdown]
# ### `datetime` 內建模組
# https://docs.python.org/zh-tw/3/tutorial/stdlib.html#dates-and-times

# %%
from datetime import datetime, date, time

# 獲取當前日期和時間
current_datetime = datetime.now()
print("當前日期和時間:", current_datetime)

# 創建一個特定的日期
specific_date = date(2023, 8, 31)
print("特定日期:", specific_date)

# 創建一個特定的時間
specific_time = time(14, 30, 0)
print("特定時間:", specific_time)

# 創建一個特定的日期和時間
specific_datetime = datetime(2023, 8, 31, 14, 30, 0)
print("特定日期和時間:", specific_datetime)

# %% [markdown]
# #### 小試身手
# 請透過 https://docs.python.org/zh-tw/3/library/datetime.html 查詢你需要使用的函數

# %%
from datetime import datetime, date, time
# 請用 datetime 內建模組印出現在的日期和時間

# 請用 datetime 內建模組將字串 “24/01/30 14:00:00” 轉換成 datetime 物件
date_str = '24/01/30 14:00:00'

# 請用 datetime 內建模組將 specific_datetime 轉成格式為 "yyyy-mm-dd hh:mm:ss" 的字串
specific_datetime = datetime(2023, 8, 31, 14, 30, 0)
# Out:
# 2023-08-31 14:30:00

# %% [markdown]
# ### 彩蛋

# %%
import this
# Out:
# The Zen of Python, by Tim Peters
#
# Beautiful is better than ugly.
# Explicit is better than implicit.
# Simple is better than complex.
# Complex is better than complicated.
# Flat is better than nested.
# Sparse is better than dense.
# Readability counts.
# Special cases aren't special enough to break the rules.
# Although practicality beats purity.
# Errors should never pass silently.
# Unless explicitly silenced.
# In the face of ambiguity, refuse the temptation to guess.
# There should be one-- and preferably only one --obvious way to do it.
# Although that way may not be obvious at first unless you're Dutch.
# Now is better than never.
# Although never is often better than *right* now.
# If the implementation is hard to explain, it's a bad idea.
# If the implementation is easy to explain, it may be a good idea.
# Namespaces are one honking great idea -- let's do more of those!
